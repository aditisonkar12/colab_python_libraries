# %%
import numpy as np

# %%
print("1d array")
a=np.array([1,2,3,4,5])
print(a)
# Out:
# 1d array
# [1 2 3 4 5]

# %%
print("2d array")
b=np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# 2d array
# [[1 2 3]
#  [4 5 6]]

# %%
print("2d array")
c=np.array([[1,2,9],[4,8,6]])
print(c)
# Out:
# 2d array
# [[1 2 9]
#  [4 8 6]]

# %%
type(a)
# Out:
# numpy.ndarray
